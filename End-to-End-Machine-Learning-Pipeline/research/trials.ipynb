# %% [markdown]
# * 若要在 colab 執行，前置作業1，建立 test.yaml 檔案

# %%
# %%writefile test.yaml
#
# name: henrykohl
# email: henglikohl425@gmail.com
# Out:
# Writing test.yaml

# %% [markdown]
# * 若要在 colab 執行，前置作業2，安裝 ensure
#
# (Lecture demo 使用 1.0.2 版本，但會產生 `AttributeError: 'TestCase' object has no attribute 'assertRaisesRegexp'Cell Execution Error` 錯誤，[參考方法](https://stackoverflow.com/questions/79008539/while-importing-methods-from-another-file-attributeerror-testcase-object-ha))

# %%
# !pip install ensure==1.0.4 -q ## colab 使用 python 3.12 ，不能使用 ensure 1.0.2

# %% [markdown]
# ---

# %%
print("Ok")
# Out:
# Ok

# %%
import yaml

yaml_file_path = "test.yaml"

# Open the YAML file and load its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)


print(data)
print(type(data))
# Out:
# {'name': 'henrykohl', 'email': 'henglikohl425@gmail.com'}
# <class 'dict'>

# %%
data['name']
# Out:
# 'henrykohl'

# %%
data['email']
# Out:
# 'henglikohl425@gmail.com'

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3422525760.py in <cell line: 0>()
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %% [markdown]
# # Configbox

# %%
from box import ConfigBox

# %%
d = ConfigBox(data)

# %%
d
# Out:
# ConfigBox({'name': 'henrykohl', 'email': 'henglikohl425@gmail.com'})

# %%
type(d)
# Out:
# box.config_box.ConfigBox

# %%
d.name
# Out:
# 'henrykohl'

# %%
d.email
# Out:
# 'henglikohl425@gmail.com'

# %% [markdown]
# # ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x=2,y=4)
# Out:
# 8

# %%
get_product(x=2,y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# /tmp/ipython-input-1816858933.py in <cell line: 0>()
# ----> 1 get_product(x=2,y="4")
#
# /usr/local/lib/python3.12/dist-packages/ensure/main.py in __call__(self, *args, **kwargs)
#     831             if not isinstance(value, templ):
#     832                 msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833                 raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     834
#     835         return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x79401e693240> does not match annotation type <class 'int'>
